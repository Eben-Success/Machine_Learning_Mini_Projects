# %%
import pandas as pd

# %%
df = pd.read_csv("/home/eben-success/Desktop/Project/Machine Learning/Linear_Regression/logistic_regression/HR_comma_sep.csv")

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.shape
# Out:
# (14999, 10)

# %%
df.rename(columns={"average_montly_hours":"average_monthly_hours"}, inplace=True)

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_monthly_hours  time_spend_company  Work_accident  left  \
# 0                        157                   3              0     1
# 1                        262                   6              0     1
# ...

# %%
df.left.unique()
# Out:
# array([1, 0])

# %%
df.Department.unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %% [markdown]
# ## Convert Categorical data numerical data

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# Assigning numerical values and storing it in another column called Dept

df["Dept"] = le.fit_transform(df["Department"])

df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_monthly_hours  time_spend_company  Work_accident  left  \
# 0                        157                   3              0     1
# 1                        262                   6              0     1
# ...

# %%
df["new_salary"] = le.fit_transform(df["salary"])

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_monthly_hours  time_spend_company  Work_accident  left  \
# 0                        157                   3              0     1
# 1                        262                   6              0     1
# ...

# %%
df.drop(["Department", "salary"], axis=1, inplace=True)

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_monthly_hours  time_spend_company  Work_accident  left  \
# 0                        157                   3              0     1
# 1                        262                   6              0     1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_monthly_hours  14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Dept                   14999 non-null  int64
#  9   new_salary             14999 non-null  int64
# dtypes: float64(2), int64(8)
# memory usage: 1.1 MB

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
one = OneHotEncoder(sparse=False, handle_unknown='error', drop='first')

# %%
onehotencoder_df = pd.DataFrame()
